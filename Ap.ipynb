# %%
from ucimlrepo import fetch_ucirepo
import pandas as pd 
import matplotlib.pyplot as plt

# %%
# fetch dataset 
car_evaluation = fetch_ucirepo(id=19) 
  
# data (as pandas dataframes) 
x = car_evaluation.data.features 
y = car_evaluation.data.targets

# %%
# variable information 
car_evaluation.variables
# Out:
#        name     role         type demographic  \
# 0    buying  Feature  Categorical        None
# 1     maint  Feature  Categorical        None
# 2     doors  Feature  Categorical        None
# 3   persons  Feature  Categorical        None
# 4  lug_boot  Feature  Categorical        None
# 5    safety  Feature  Categorical        None
# 6     class   Target  Categorical        None
#
#                                          description units missing_values
# 0                                       buying price  None             no
# 1                           price of the maintenance  None             no
# 2                                    number of doors  None             no
# 3              capacity in terms of persons to carry  None             no
# 4                           the size of luggage boot  None             no
# 5                        estimated safety of the car  None             no
# 6  evaulation level (unacceptable, acceptable, go...  None             no

# %%
x
# Out:
#      buying  maint  doors persons lug_boot safety
# 0     vhigh  vhigh      2       2    small    low
# 1     vhigh  vhigh      2       2    small    med
# 2     vhigh  vhigh      2       2    small   high
# 3     vhigh  vhigh      2       2      med    low
# 4     vhigh  vhigh      2       2      med    med
# ...     ...    ...    ...     ...      ...    ...
# 1723    low    low  5more    more      med    med
# 1724    low    low  5more    more      med   high
# 1725    low    low  5more    more      big    low
# 1726    low    low  5more    more      big    med
# 1727    low    low  5more    more      big   high
#
# [1728 rows x 6 columns]

# %%
y.head()
# Out:
#    class
# 0  unacc
# 1  unacc
# 2  unacc
# 3  unacc
# 4  unacc

# %%
for i in x:
    print(i,":=",list(x[i].unique()))

print("class :=",list(y['class'].unique()))
# Out:
# buying := ['vhigh', 'high', 'med', 'low']
# maint := ['vhigh', 'high', 'med', 'low']
# doors := ['2', '3', '4', '5more']
# persons := ['2', '4', 'more']
# lug_boot := ['small', 'med', 'big']
# safety := ['low', 'med', 'high']
# class := ['unacc', 'acc', 'vgood', 'good']

# %%
# preprocessing of data
# converting data into transaction format

dataset=x
dataset['class']=y['class']
encoded_dataset = pd.get_dummies(dataset)
encoded_dataset
# Out:
#       buying_high  buying_low  buying_med  buying_vhigh  maint_high  \
# 0           False       False       False          True       False
# 1           False       False       False          True       False
# 2           False       False       False          True       False
# 3           False       False       False          True       False
# 4           False       False       False          True       False
# ...           ...         ...         ...           ...         ...
# 1723        False        True       False         False       False
# 1724        False        True       False         False       False
# 1725        False        True       False         False       False
# 1726        False        True       False         False       False
# 1727        False        True       False         False       False
#
#       maint_low  maint_med  maint_vhigh  doors_2  doors_3  ...  lug_boot_big  \
# 0         False      False         True     True    False  ...         False
# 1         False      False         True     True    False  ...         False
# 2         False      False         True     True    False  ...         False
# 3         False      False         True     True    False  ...         False
# 4         False      False         True     True    False  ...         False
# ...         ...        ...          ...      ...      ...  ...           ...
# 1723       True      False        False    False    False  ...         False
# 1724       True      False        False    False    False  ...         False
# 1725       True      False        False    False    False  ...          True
# 1726       True      False        False    False    False  ...          True
# 1727       True      False        False    False    False  ...          True
#
#       lug_boot_med  lug_boot_small  safety_high  safety_low  safety_med  \
# 0            False            True        False        True       False
# 1            False            True        False       False        True
# 2            False            True         True       False       False
# 3             True           False        False        True       False
# 4             True           False        False       False        True
# ...            ...             ...          ...         ...         ...
# 1723          True           False        False       False        True
# 1724          True           False         True       False       False
# 1725         False           False        False        True       False
# 1726         False           False        False       False        True
# 1727         False           False         True       False       False
#
#       class_acc  class_good  class_unacc  class_vgood
# 0         False       False         True        False
# 1         False       False         True        False
# 2         False       False         True        False
# 3         False       False         True        False
# 4         False       False         True        False
# ...         ...         ...          ...          ...
# 1723      False        True        False        False
# 1724      False       False        False         True
# 1725      False       False         True        False
# 1726      False        True        False        False
# 1727      False       False        False         True
#
# [1728 rows x 25 columns]

# %%
from mlxtend.frequent_patterns import apriori

frequent_itemsets = apriori(encoded_dataset, min_support=0.0000000001, use_colnames=True)

# %%
frequent_itemsets
# Out:
#         support                                           itemsets
# 0      0.250000                           frozenset({buying_high})
# 1      0.250000                            frozenset({buying_low})
# 2      0.250000                            frozenset({buying_med})
# 3      0.250000                          frozenset({buying_vhigh})
# 4      0.250000                            frozenset({maint_high})
# ...         ...                                                ...
# 20363  0.000579  frozenset({maint_vhigh, safety_low, class_unac...
# 20364  0.000579  frozenset({maint_vhigh, class_unacc, buying_vh...
# 20365  0.000579  frozenset({maint_vhigh, class_unacc, buying_vh...
# 20366  0.000579  frozenset({maint_vhigh, safety_low, class_unac...
# 20367  0.000579  frozenset({maint_vhigh, class_unacc, buying_vh...
#
# [20368 rows x 2 columns]

# %%
from mlxtend.frequent_patterns import association_rules

rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.5)

# %%
rules
# Out:
#                                              antecedents  \
# 0                               frozenset({buying_high})
# 1                                frozenset({class_good})
# 2                                frozenset({buying_low})
# 3                               frozenset({class_vgood})
# 4                                frozenset({buying_med})
# ...                                                  ...
# 24166  frozenset({maint_vhigh, class_unacc, lug_boot_...
# 24167  frozenset({maint_vhigh, buying_vhigh, lug_boot...
# 24168  frozenset({class_unacc, buying_vhigh, lug_boot...
# 24169  frozenset({maint_vhigh, safety_low, buying_vhi...
# 24170  frozenset({maint_vhigh, buying_vhigh, safety_m...
#
#                      consequents  antecedent support  consequent support  \
# 0       frozenset({class_unacc})            0.250000            0.700231
# 1        frozenset({buying_low})            0.039931            0.250000
# 2       frozenset({class_unacc})            0.250000            0.700231
# 3        frozenset({buying_low})            0.037616            0.250000
# 4       frozenset({class_unacc})            0.250000            0.700231
# ...                          ...                 ...                 ...
# 24166  frozenset({buying_vhigh})            0.001157            0.250000
# 24167   frozenset({class_unacc})            0.000579            0.700231
# 24168   frozenset({maint_vhigh})            0.001157            0.250000
# 24169   frozenset({class_unacc})            0.000579            0.700231
# 24170   frozenset({class_unacc})            0.000579            0.700231
#
#         support  confidence      lift  representativity  leverage  conviction  \
# 0      0.187500    0.750000  1.071074               1.0  0.012442    1.199074
# 1      0.026620    0.666667  2.666667               1.0  0.016638    2.250000
# 2      0.149306    0.597222  0.852893               1.0 -0.025752    0.744253
# 3      0.022569    0.600000  2.400000               1.0  0.013166    1.875000
# 4      0.155093    0.620370  0.885950               1.0 -0.019965    0.789634
# ...         ...         ...       ...               ...       ...         ...
# 24166  0.000579    0.500000  2.000000               1.0  0.000289    1.500000
# 24167  0.000579    1.000000  1.428099               1.0  0.000173         inf
# 24168  0.000579    0.500000  2.000000               1.0  0.000289    1.500000
# 24169  0.000579    1.000000  1.428099               1.0  0.000173         inf
# 24170  0.000579    1.000000  1.428099               1.0  0.000173         inf
#
#        zhangs_metric   jaccard  certainty  kulczynski
# 0           0.088477  0.245827   0.166023    0.508884
# 1           0.650995  0.101099   0.555556    0.386574
# 2          -0.186975  0.186416  -0.343629    0.405223
# 3           0.606133  0.085153   0.466667    0.345139
# 4          -0.146497  0.195051  -0.266409    0.420929
# ...              ...       ...        ...         ...
# 24166       0.500579  0.002309   0.333333    0.251157
# 24167       0.299942  0.000826   1.000000    0.500413
# 24168       0.500579  0.002309   0.333333    0.251157
# 24169       0.299942  0.000826   1.000000    0.500413
# 24170       0.299942  0.000826   1.000000    0.500413
#
# [24171 rows x 14 columns]

# %%
rules = rules[rules.apply(lambda x: all('class_' in item for item in x['consequents']) and 
                          not any('class_' in item for item in x['antecedents']),axis=1)]

# rules = rules[rules['lift'] > 1.2]

rules
# Out:
#                                              antecedents  \
# 0                               frozenset({buying_high})
# 2                                frozenset({buying_low})
# 4                                frozenset({buying_med})
# 5                              frozenset({buying_vhigh})
# 6                                frozenset({maint_high})
# ...                                                  ...
# 24162  frozenset({maint_vhigh, safety_low, buying_vhi...
# 24164  frozenset({maint_vhigh, buying_vhigh, safety_m...
# 24167  frozenset({maint_vhigh, buying_vhigh, lug_boot...
# 24169  frozenset({maint_vhigh, safety_low, buying_vhi...
# 24170  frozenset({maint_vhigh, buying_vhigh, safety_m...
#
#                     consequents  antecedent support  consequent support  \
# 0      frozenset({class_unacc})            0.250000            0.700231
# 2      frozenset({class_unacc})            0.250000            0.700231
# 4      frozenset({class_unacc})            0.250000            0.700231
# 5      frozenset({class_unacc})            0.250000            0.700231
# 6      frozenset({class_unacc})            0.250000            0.700231
# ...                         ...                 ...                 ...
# 24162  frozenset({class_unacc})            0.000579            0.700231
# 24164  frozenset({class_unacc})            0.000579            0.700231
# 24167  frozenset({class_unacc})            0.000579            0.700231
# 24169  frozenset({class_unacc})            0.000579            0.700231
# 24170  frozenset({class_unacc})            0.000579            0.700231
#
#         support  confidence      lift  representativity  leverage  conviction  \
# 0      0.187500    0.750000  1.071074               1.0  0.012442    1.199074
# 2      0.149306    0.597222  0.852893               1.0 -0.025752    0.744253
# 4      0.155093    0.620370  0.885950               1.0 -0.019965    0.789634
# 5      0.208333    0.833333  1.190083               1.0  0.033275    1.798611
# 6      0.181713    0.726852  1.038017               1.0  0.006655    1.097458
# ...         ...         ...       ...               ...       ...         ...
# 24162  0.000579    1.000000  1.428099               1.0  0.000173         inf
# 24164  0.000579    1.000000  1.428099               1.0  0.000173         inf
# 24167  0.000579    1.000000  1.428099               1.0  0.000173         inf
# 24169  0.000579    1.000000  1.428099               1.0  0.000173         inf
# 24170  0.000579    1.000000  1.428099               1.0  0.000173         inf
#
#        zhangs_metric   jaccard  certainty  kulczynski
# 0           0.088477  0.245827   0.166023    0.508884
# 2          -0.186975  0.186416  -0.343629    0.405223
# 4          -0.146497  0.195051  -0.266409    0.420929
# 5           0.212963  0.280811   0.444015    0.565427
# 6           0.048832  0.236446   0.088803    0.493178
# ...              ...       ...        ...         ...
# 24162       0.299942  0.000826   1.000000    0.500413
# 24164       0.299942  0.000826   1.000000    0.500413
# 24167       0.299942  0.000826   1.000000    0.500413
# 24169       0.299942  0.000826   1.000000    0.500413
# 24170       0.299942  0.000826   1.000000    0.500413
#
# [7868 rows x 14 columns]

# %%
def predict(instance, rules):
    for _, rule in rules.iterrows():
        antecedents = list(rule['antecedents'])
        
        if all(instance[item] == 1 for item in antecedents):
            for c in rule['consequents']:
                if "class_" in c:
                    return c
    return "class_acc"

# %%
dataset['class'].value_counts()
# Out:
# class
# unacc    1210
# acc       384
# good       69
# vgood      65
# Name: count, dtype: int64

# %%
# Visualize class distribution
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

class_counts = dataset['class'].value_counts()
colors = ['#e74c3c', '#3498db', '#2ecc71', '#f39c12']

axes[0].bar(class_counts.index, class_counts.values, color=colors, edgecolor='black')
axes[0].set_title('Class Distribution (Bar Chart)', fontsize=13, fontweight='bold')
axes[0].set_xlabel('Class')
axes[0].set_ylabel('Count')
for i, v in enumerate(class_counts.values):
    axes[0].text(i, v + 5, str(v), ha='center', fontweight='bold')

axes[1].pie(class_counts.values, labels=class_counts.index, colors=colors,
            autopct='%1.1f%%', startangle=140, shadow=True)
axes[1].set_title('Class Distribution (Pie Chart)', fontsize=13, fontweight='bold')

plt.tight_layout()
plt.savefig('class_distribution.png', dpi=150, bbox_inches='tight')
plt.show()
print('\nNote: Dataset is highly imbalanced — unacc dominates at ~70%')
# Out:
# Note: Dataset is highly imbalanced — unacc dominates at ~70%
